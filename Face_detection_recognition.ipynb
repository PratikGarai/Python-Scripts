# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
file = open('Hello.txt','w')
file.write('Hello file!!!')
file.close()

# %%
im = open('image.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-87289ebc22c4> in <module>
# ----> 1 im = open('image.png')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image.png'

# %%
im = open('image')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c4dfba6f481a> in <module>
# ----> 1 im = open('image')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\RITIKA SARKAR'

# %%
im = open('image.png')
del im

# %%
img_raw = cv2.imread('image.png')
print(type(img_raw))
print(img_raw.shape)
# Out:
# <class 'numpy.ndarray'>
# (288, 288, 3)

# %%
plt.imshow(img_raw)

# %%
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
image_blank=np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(image_blank)

# %%
line_red=cv2.line(image_blank,(0,0),(511,511),(255,0,0),5)
plt.imshow(line_red)

# %%
rectangle=cv2.rectangle(image_blank,(384,0),(510,128),(0,0,255),5)
plt.imshow(image_blank)

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
text=cv2.putText(image_blank,'OpenCV',(10,500),font,4,(255,255,255),2,cv2.LINE_AA)
plt.imshow(text)

# %%
text=cv2.putText(image_blank,'OpenCV',(10,500),font,6,(255,255,255),2,cv2.LINE_AA)
plt.imshow(text)

# %%
text=cv2.putText(image_blank,'OpenCV',(10,200),font,1,(255,255,255),2,cv2.LINE_AA)
text=cv2.putText(image_blank,'OpenCV',(10,200),font,2,(255,255,255),2,cv2.LINE_AA)
plt.imshow(image_blank)

# %%
bill=cv2.imread('billy.jpg')
b=bill.copy()
bill_gray=cv2.cvtColor(b,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml').detectMultiScale(bill_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(b,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(cv2.cvtColor(b,cv2.COLOR_RGB2BGR))

# %%
rob=cv2.imread('robert.jpg')
r=rob.copy()
r_gray=cv2.cvtColor(r,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml').detectMultiScale(r_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(r,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(cv2.cvtColor(r,cv2.COLOR_RGB2BGR))

# %%
bill=cv2.imread('billy.jpg')
b=bill.copy()
bill_gray=cv2.cvtColor(b,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\git\\haarcascade_mcs_nose.xml').detectMultiScale(bill_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(b,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(b,cv2.COLOR_RGB2BGR))

# %%
bill=cv2.imread('billy.jpg')
b=bill.copy()
bill_gray=cv2.cvtColor(b,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\git\\haarcascade_mcs_mouth.xml').detectMultiScale(bill_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(b,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(b,cv2.COLOR_RGB2BGR))

# %%
ci=cv2.imread('cr7.jpg')
c=ci.copy()
c_gray=cv2.cvtColor(c,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\git\\haarcascade_mcs_leftear.xml').detectMultiScale(c_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(c,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(cv2.cvtColor(c,cv2.COLOR_RGB2BGR))

# %%
tea=cv2.imread('team.jpg')
t=tea.copy()
t_gray=cv2.cvtColor(t,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml').detectMultiScale(t_gray,scaleFactor=1.1,minNeighbors=5)
for (x,y,w,h) in face:
    cv2.rectangle(t,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(cv2.cvtColor(t,cv2.COLOR_RGB2BGR))

# %%
tea=cv2.imread('team.jpg')
t=tea.copy()
t_gray=cv2.cvtColor(t,cv2.COLOR_BGR2GRAY)
face= cv2.CascadeClassifier('C:\\Users\\RITIKA SARKAR\\AppData\\Local\\Programs\\Python\\Python36-32\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml').detectMultiScale(t_gray,scaleFactor=1.1,minNeighbors=3)
for (x,y,w,h) in face:
    cv2.rectangle(t,(x,y),(x+w,y+h),(0,255,0),5)
plt.imshow(cv2.cvtColor(t,cv2.COLOR_RGB2BGR))
